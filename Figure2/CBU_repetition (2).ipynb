# %% [markdown]
# # mor

# %%
import pandas as pd
accuracy_rf_02 = pd.read_csv('accuracy_rf_mor_0.2.csv', index_col=0) 
accuracy_rf_025 = pd.read_csv('accuracy_rf_mor_0.25.csv', index_col=0)
accuracy_rf_03 = pd.read_csv('accuracy_rf_mor_0.3.csv', index_col=0) 
accuracy_rf_035 = pd.read_csv('accuracy_rf_mor_0.35.csv', index_col=0) 
accuracy_rf_04 = pd.read_csv('accuracy_rf_mor_0.4.csv', index_col=0) 
accuracy_rf_045 = pd.read_csv('accuracy_rf_mor_0.45.csv', index_col=0) 
accuracy_rf_05 = pd.read_csv('accuracy_rf_mor_0.5.csv', index_col=0) 

# RF 0.2
mean_of_accuracy_rf_02=accuracy_rf_02.iloc[:, 1].mean()
std_of_accuracy_rf_02=accuracy_rf_02.iloc[:, 1].std()
mean_of_F_rf_02=accuracy_rf_02.iloc[:, 2].mean()
std_of_F_rf_02=accuracy_rf_02.iloc[:, 2].std()

# RF 0.25
mean_of_accuracy_rf_025=accuracy_rf_025.iloc[:, 1].mean()
std_of_accuracy_rf_025=accuracy_rf_025.iloc[:, 1].std()
mean_of_F_rf_025=accuracy_rf_025.iloc[:, 2].mean()
std_of_F_rf_025=accuracy_rf_025.iloc[:, 2].std()

# RF 0.3
mean_of_accuracy_rf_03=accuracy_rf_03.iloc[:, 1].mean()
std_of_accuracy_rf_03=accuracy_rf_03.iloc[:, 1].std()
mean_of_F_rf_03=accuracy_rf_03.iloc[:, 2].mean()
std_of_F_rf_03=accuracy_rf_03.iloc[:, 2].std()

# RF 0.35
mean_of_accuracy_rf_035=accuracy_rf_035.iloc[:, 1].mean()
std_of_accuracy_rf_035=accuracy_rf_035.iloc[:, 1].std()
mean_of_F_rf_035=accuracy_rf_035.iloc[:, 2].mean()
std_of_F_rf_035=accuracy_rf_035.iloc[:, 2].std()

# RF 0.4
mean_of_accuracy_rf_04=accuracy_rf_04.iloc[:, 1].mean()
std_of_accuracy_rf_04=accuracy_rf_04.iloc[:, 1].std()
mean_of_F_rf_04=accuracy_rf_04.iloc[:, 2].mean()
std_of_F_rf_04=accuracy_rf_04.iloc[:, 2].std()

# RF 0.45
mean_of_accuracy_rf_045=accuracy_rf_045.iloc[:, 1].mean()
std_of_accuracy_rf_045=accuracy_rf_045.iloc[:, 1].std()
mean_of_F_rf_045=accuracy_rf_045.iloc[:, 2].mean()
std_of_F_rf_045=accuracy_rf_045.iloc[:, 2].std()

# RF 0.5
mean_of_accuracy_rf_05=accuracy_rf_05.iloc[:, 1].mean()
std_of_accuracy_rf_05=accuracy_rf_05.iloc[:, 1].std()
mean_of_F_rf_05=accuracy_rf_05.iloc[:, 2].mean()
std_of_F_rf_05=accuracy_rf_05.iloc[:, 2].std()

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.size']=10

x = [0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

y = [mean_of_accuracy_rf_02, mean_of_accuracy_rf_025, mean_of_accuracy_rf_03,
     mean_of_accuracy_rf_035, mean_of_accuracy_rf_04, mean_of_accuracy_rf_045,
     mean_of_accuracy_rf_05]

yerr = [std_of_accuracy_rf_02, std_of_accuracy_rf_025, std_of_accuracy_rf_03,
     std_of_accuracy_rf_035, std_of_accuracy_rf_04, std_of_accuracy_rf_045,
     std_of_accuracy_rf_05]

plt.errorbar(x, y, yerr=yerr, capsize=3, elinewidth=1)
plt.scatter(x, y)
for xi, yi in zip(x, y):
    plt.text(xi, yi + 0.01, f"{yi:.3f}", ha='center', va='bottom')
plt.xlabel('ratio of test data')
plt.ylabel('accuracy')
plt.ylim(0.6, 1.0)
plt.show()

import matplotlib.pyplot as plt
plt.rcParams['font.size']=10

x = [0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

y = [mean_of_F_rf_02, mean_of_F_rf_025, mean_of_F_rf_03,
     mean_of_F_rf_035, mean_of_F_rf_04, mean_of_F_rf_045,
     mean_of_F_rf_05]

yerr = [std_of_F_rf_02, std_of_F_rf_025, std_of_F_rf_03,
     std_of_F_rf_035, std_of_F_rf_04, std_of_F_rf_045,
     std_of_F_rf_05]

plt.errorbar(x, y, yerr=yerr, capsize=3, elinewidth=1)
plt.scatter(x, y)
for xi, yi in zip(x, y):
    plt.text(xi, yi + 0.01, f"{yi:.3f}", ha='center', va='bottom')
plt.xlabel('ratio of test data')
plt.ylabel('F-measure')
plt.ylim(0.6, 1.0)
plt.show()

# %% [markdown]
# # sod

# %%
import pandas as pd
accuracy_rf_02 = pd.read_csv('accuracy_rf_sod_0.2.csv', index_col=0) 
accuracy_rf_025 = pd.read_csv('accuracy_rf_sod_0.25.csv', index_col=0)
accuracy_rf_03 = pd.read_csv('accuracy_rf_sod_0.3.csv', index_col=0) 
accuracy_rf_035 = pd.read_csv('accuracy_rf_sod_0.35.csv', index_col=0) 
accuracy_rf_04 = pd.read_csv('accuracy_rf_sod_0.4.csv', index_col=0) 
accuracy_rf_045 = pd.read_csv('accuracy_rf_sod_0.45.csv', index_col=0) 
accuracy_rf_05 = pd.read_csv('accuracy_rf_sod_0.5.csv', index_col=0) 

# RF 0.2
mean_of_accuracy_rf_02=accuracy_rf_02.iloc[:, 1].mean()
std_of_accuracy_rf_02=accuracy_rf_02.iloc[:, 1].std()
mean_of_F_rf_02=accuracy_rf_02.iloc[:, 2].mean()
std_of_F_rf_02=accuracy_rf_02.iloc[:, 2].std()

# RF 0.25
mean_of_accuracy_rf_025=accuracy_rf_025.iloc[:, 1].mean()
std_of_accuracy_rf_025=accuracy_rf_025.iloc[:, 1].std()
mean_of_F_rf_025=accuracy_rf_025.iloc[:, 2].mean()
std_of_F_rf_025=accuracy_rf_025.iloc[:, 2].std()

# RF 0.3
mean_of_accuracy_rf_03=accuracy_rf_03.iloc[:, 1].mean()
std_of_accuracy_rf_03=accuracy_rf_03.iloc[:, 1].std()
mean_of_F_rf_03=accuracy_rf_03.iloc[:, 2].mean()
std_of_F_rf_03=accuracy_rf_03.iloc[:, 2].std()

# RF 0.35
mean_of_accuracy_rf_035=accuracy_rf_035.iloc[:, 1].mean()
std_of_accuracy_rf_035=accuracy_rf_035.iloc[:, 1].std()
mean_of_F_rf_035=accuracy_rf_035.iloc[:, 2].mean()
std_of_F_rf_035=accuracy_rf_035.iloc[:, 2].std()

# RF 0.4
mean_of_accuracy_rf_04=accuracy_rf_04.iloc[:, 1].mean()
std_of_accuracy_rf_04=accuracy_rf_04.iloc[:, 1].std()
mean_of_F_rf_04=accuracy_rf_04.iloc[:, 2].mean()
std_of_F_rf_04=accuracy_rf_04.iloc[:, 2].std()

# RF 0.45
mean_of_accuracy_rf_045=accuracy_rf_045.iloc[:, 1].mean()
std_of_accuracy_rf_045=accuracy_rf_045.iloc[:, 1].std()
mean_of_F_rf_045=accuracy_rf_045.iloc[:, 2].mean()
std_of_F_rf_045=accuracy_rf_045.iloc[:, 2].std()

# RF 0.5
mean_of_accuracy_rf_05=accuracy_rf_05.iloc[:, 1].mean()
std_of_accuracy_rf_05=accuracy_rf_05.iloc[:, 1].std()
mean_of_F_rf_05=accuracy_rf_05.iloc[:, 2].mean()
std_of_F_rf_05=accuracy_rf_05.iloc[:, 2].std()

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.size']=10

x = [0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

y = [mean_of_accuracy_rf_02, mean_of_accuracy_rf_025, mean_of_accuracy_rf_03,
     mean_of_accuracy_rf_035, mean_of_accuracy_rf_04, mean_of_accuracy_rf_045,
     mean_of_accuracy_rf_05]

yerr = [std_of_accuracy_rf_02, std_of_accuracy_rf_025, std_of_accuracy_rf_03,
     std_of_accuracy_rf_035, std_of_accuracy_rf_04, std_of_accuracy_rf_045,
     std_of_accuracy_rf_05]

plt.errorbar(x, y, yerr=yerr, capsize=3, elinewidth=1)
plt.scatter(x, y)
for xi, yi in zip(x, y):
    plt.text(xi, yi + 0.01, f"{yi:.3f}", ha='center', va='bottom')
plt.xlabel('ratio of test data')
plt.ylabel('accuracy')
plt.ylim(0.6, 1.0)
plt.show()

import matplotlib.pyplot as plt
plt.rcParams['font.size']=12

x = [0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

y = [mean_of_F_rf_02, mean_of_F_rf_025, mean_of_F_rf_03,
     mean_of_F_rf_035, mean_of_F_rf_04, mean_of_F_rf_045,
     mean_of_F_rf_05]

yerr = [std_of_F_rf_02, std_of_F_rf_025, std_of_F_rf_03,
     std_of_F_rf_035, std_of_F_rf_04, std_of_F_rf_045,
     std_of_F_rf_05]

plt.errorbar(x, y, yerr=yerr, capsize=3, elinewidth=1)
plt.scatter(x, y)
for xi, yi in zip(x, y):
    plt.text(xi, yi + 0.01, f"{yi:.3f}", ha='center', va='bottom')
plt.xlabel('ratio of test data')
plt.ylabel('F-measure')
plt.ylim(0.6, 1.0)
plt.show()

# %% [markdown]
# # d6r

# %%
import pandas as pd
accuracy_rf_02 = pd.read_csv('accuracy_rf_d6r_0.2.csv', index_col=0) 
accuracy_rf_025 = pd.read_csv('accuracy_rf_d6r_0.25.csv', index_col=0)
accuracy_rf_03 = pd.read_csv('accuracy_rf_d6r_0.3.csv', index_col=0) 
accuracy_rf_035 = pd.read_csv('accuracy_rf_d6r_0.35.csv', index_col=0) 
accuracy_rf_04 = pd.read_csv('accuracy_rf_d6r_0.4.csv', index_col=0) 
accuracy_rf_045 = pd.read_csv('accuracy_rf_d6r_0.45.csv', index_col=0) 
accuracy_rf_05 = pd.read_csv('accuracy_rf_d6r_0.5.csv', index_col=0) 

# RF 0.2
mean_of_accuracy_rf_02=accuracy_rf_02.iloc[:, 1].mean()
std_of_accuracy_rf_02=accuracy_rf_02.iloc[:, 1].std()
mean_of_F_rf_02=accuracy_rf_02.iloc[:, 2].mean()
std_of_F_rf_02=accuracy_rf_02.iloc[:, 2].std()

# RF 0.25
mean_of_accuracy_rf_025=accuracy_rf_025.iloc[:, 1].mean()
std_of_accuracy_rf_025=accuracy_rf_025.iloc[:, 1].std()
mean_of_F_rf_025=accuracy_rf_025.iloc[:, 2].mean()
std_of_F_rf_025=accuracy_rf_025.iloc[:, 2].std()

# RF 0.3
mean_of_accuracy_rf_03=accuracy_rf_03.iloc[:, 1].mean()
std_of_accuracy_rf_03=accuracy_rf_03.iloc[:, 1].std()
mean_of_F_rf_03=accuracy_rf_03.iloc[:, 2].mean()
std_of_F_rf_03=accuracy_rf_03.iloc[:, 2].std()

# RF 0.35
mean_of_accuracy_rf_035=accuracy_rf_035.iloc[:, 1].mean()
std_of_accuracy_rf_035=accuracy_rf_035.iloc[:, 1].std()
mean_of_F_rf_035=accuracy_rf_035.iloc[:, 2].mean()
std_of_F_rf_035=accuracy_rf_035.iloc[:, 2].std()

# RF 0.4
mean_of_accuracy_rf_04=accuracy_rf_04.iloc[:, 1].mean()
std_of_accuracy_rf_04=accuracy_rf_04.iloc[:, 1].std()
mean_of_F_rf_04=accuracy_rf_04.iloc[:, 2].mean()
std_of_F_rf_04=accuracy_rf_04.iloc[:, 2].std()

# RF 0.45
mean_of_accuracy_rf_045=accuracy_rf_045.iloc[:, 1].mean()
std_of_accuracy_rf_045=accuracy_rf_045.iloc[:, 1].std()
mean_of_F_rf_045=accuracy_rf_045.iloc[:, 2].mean()
std_of_F_rf_045=accuracy_rf_045.iloc[:, 2].std()

# RF 0.5
mean_of_accuracy_rf_05=accuracy_rf_05.iloc[:, 1].mean()
std_of_accuracy_rf_05=accuracy_rf_05.iloc[:, 1].std()
mean_of_F_rf_05=accuracy_rf_05.iloc[:, 2].mean()
std_of_F_rf_05=accuracy_rf_05.iloc[:, 2].std()

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.size']=10

x = [0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

y = [mean_of_accuracy_rf_02, mean_of_accuracy_rf_025, mean_of_accuracy_rf_03,
     mean_of_accuracy_rf_035, mean_of_accuracy_rf_04, mean_of_accuracy_rf_045,
     mean_of_accuracy_rf_05]

yerr = [std_of_accuracy_rf_02, std_of_accuracy_rf_025, std_of_accuracy_rf_03,
     std_of_accuracy_rf_035, std_of_accuracy_rf_04, std_of_accuracy_rf_045,
     std_of_accuracy_rf_05]

plt.errorbar(x, y, yerr=yerr, capsize=3, elinewidth=1)
plt.scatter(x, y)
for xi, yi in zip(x, y):
    plt.text(xi, yi + 0.01, f"{yi:.3f}", ha='center', va='bottom')
plt.xlabel('ratio of test data')
plt.ylabel('accuracy')
plt.ylim(0.6, 1.0)
plt.show()

import matplotlib.pyplot as plt
plt.rcParams['font.size']=10

x = [0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

y = [mean_of_F_rf_02, mean_of_F_rf_025, mean_of_F_rf_03,
     mean_of_F_rf_035, mean_of_F_rf_04, mean_of_F_rf_045,
     mean_of_F_rf_05]

yerr = [std_of_F_rf_02, std_of_F_rf_025, std_of_F_rf_03,
     std_of_F_rf_035, std_of_F_rf_04, std_of_F_rf_045,
     std_of_F_rf_05]

plt.errorbar(x, y, yerr=yerr, capsize=3, elinewidth=1)
plt.scatter(x, y)
for xi, yi in zip(x, y):
    plt.text(xi, yi + 0.01, f"{yi:.3f}", ha='center', va='bottom')
plt.xlabel('ratio of test data')
plt.ylabel('F-measure')
plt.ylim(0.6, 1.0)
plt.show()

# %% [markdown]
# # can

# %%
import pandas as pd
accuracy_rf_02 = pd.read_csv('accuracy_rf_can_0.2.csv', index_col=0) 
accuracy_rf_025 = pd.read_csv('accuracy_rf_can_0.25.csv', index_col=0)
accuracy_rf_03 = pd.read_csv('accuracy_rf_can_0.3.csv', index_col=0) 
accuracy_rf_035 = pd.read_csv('accuracy_rf_can_0.35.csv', index_col=0) 
accuracy_rf_04 = pd.read_csv('accuracy_rf_can_0.4.csv', index_col=0) 
accuracy_rf_045 = pd.read_csv('accuracy_rf_can_0.45.csv', index_col=0) 
accuracy_rf_05 = pd.read_csv('accuracy_rf_can_0.5.csv', index_col=0) 

# RF 0.2
mean_of_accuracy_rf_02=accuracy_rf_02.iloc[:, 1].mean()
std_of_accuracy_rf_02=accuracy_rf_02.iloc[:, 1].std()
mean_of_F_rf_02=accuracy_rf_02.iloc[:, 2].mean()
std_of_F_rf_02=accuracy_rf_02.iloc[:, 2].std()

# RF 0.25
mean_of_accuracy_rf_025=accuracy_rf_025.iloc[:, 1].mean()
std_of_accuracy_rf_025=accuracy_rf_025.iloc[:, 1].std()
mean_of_F_rf_025=accuracy_rf_025.iloc[:, 2].mean()
std_of_F_rf_025=accuracy_rf_025.iloc[:, 2].std()

# RF 0.3
mean_of_accuracy_rf_03=accuracy_rf_03.iloc[:, 1].mean()
std_of_accuracy_rf_03=accuracy_rf_03.iloc[:, 1].std()
mean_of_F_rf_03=accuracy_rf_03.iloc[:, 2].mean()
std_of_F_rf_03=accuracy_rf_03.iloc[:, 2].std()

# RF 0.35
mean_of_accuracy_rf_035=accuracy_rf_035.iloc[:, 1].mean()
std_of_accuracy_rf_035=accuracy_rf_035.iloc[:, 1].std()
mean_of_F_rf_035=accuracy_rf_035.iloc[:, 2].mean()
std_of_F_rf_035=accuracy_rf_035.iloc[:, 2].std()

# RF 0.4
mean_of_accuracy_rf_04=accuracy_rf_04.iloc[:, 1].mean()
std_of_accuracy_rf_04=accuracy_rf_04.iloc[:, 1].std()
mean_of_F_rf_04=accuracy_rf_04.iloc[:, 2].mean()
std_of_F_rf_04=accuracy_rf_04.iloc[:, 2].std()

# RF 0.45
mean_of_accuracy_rf_045=accuracy_rf_045.iloc[:, 1].mean()
std_of_accuracy_rf_045=accuracy_rf_045.iloc[:, 1].std()
mean_of_F_rf_045=accuracy_rf_045.iloc[:, 2].mean()
std_of_F_rf_045=accuracy_rf_045.iloc[:, 2].std()

# RF 0.5
mean_of_accuracy_rf_05=accuracy_rf_05.iloc[:, 1].mean()
std_of_accuracy_rf_05=accuracy_rf_05.iloc[:, 1].std()
mean_of_F_rf_05=accuracy_rf_05.iloc[:, 2].mean()
std_of_F_rf_05=accuracy_rf_05.iloc[:, 2].std()

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.size']=12

x = [0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

y = [mean_of_accuracy_rf_02, mean_of_accuracy_rf_025, mean_of_accuracy_rf_03,
     mean_of_accuracy_rf_035, mean_of_accuracy_rf_04, mean_of_accuracy_rf_045,
     mean_of_accuracy_rf_05]

yerr = [std_of_accuracy_rf_02, std_of_accuracy_rf_025, std_of_accuracy_rf_03,
     std_of_accuracy_rf_035, std_of_accuracy_rf_04, std_of_accuracy_rf_045,
     std_of_accuracy_rf_05]

plt.errorbar(x, y, yerr=yerr, capsize=3, elinewidth=1)
plt.scatter(x, y)
for xi, yi in zip(x, y):
    plt.text(xi, yi + 0.01, f"{yi:.3f}", ha='center', va='bottom')
plt.xlabel('ratio of test data')
plt.ylabel('accuracy')
plt.ylim(0.6, 1.0)
plt.show()

import matplotlib.pyplot as plt
plt.rcParams['font.size']=12

x = [0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

y = [mean_of_F_rf_02, mean_of_F_rf_025, mean_of_F_rf_03,
     mean_of_F_rf_035, mean_of_F_rf_04, mean_of_F_rf_045,
     mean_of_F_rf_05]

yerr = [std_of_F_rf_02, std_of_F_rf_025, std_of_F_rf_03,
     std_of_F_rf_035, std_of_F_rf_04, std_of_F_rf_045,
     std_of_F_rf_05]

plt.errorbar(x, y, yerr=yerr, capsize=3, elinewidth=1)
plt.scatter(x, y)
for xi, yi in zip(x, y):
    plt.text(xi, yi + 0.01, f"{yi:.3f}", ha='center', va='bottom')
plt.xlabel('ratio of test data')
plt.ylabel('F-measure')
plt.ylim(0.6, 1.0)
plt.show()

# %% [markdown]
# # jbw

# %%
import pandas as pd
accuracy_rf_02 = pd.read_csv('accuracy_rf_jbw_0.2.csv', index_col=0) 
accuracy_rf_025 = pd.read_csv('accuracy_rf_jbw_0.25.csv', index_col=0)
accuracy_rf_03 = pd.read_csv('accuracy_rf_jbw_0.3.csv', index_col=0) 
accuracy_rf_035 = pd.read_csv('accuracy_rf_jbw_0.35.csv', index_col=0) 
accuracy_rf_04 = pd.read_csv('accuracy_rf_jbw_0.4.csv', index_col=0) 
accuracy_rf_045 = pd.read_csv('accuracy_rf_jbw_0.45.csv', index_col=0) 
accuracy_rf_05 = pd.read_csv('accuracy_rf_jbw_0.5.csv', index_col=0) 

# RF 0.2
mean_of_accuracy_rf_02=accuracy_rf_02.iloc[:, 1].mean()
std_of_accuracy_rf_02=accuracy_rf_02.iloc[:, 1].std()
mean_of_F_rf_02=accuracy_rf_02.iloc[:, 2].mean()
std_of_F_rf_02=accuracy_rf_02.iloc[:, 2].std()

# RF 0.25
mean_of_accuracy_rf_025=accuracy_rf_025.iloc[:, 1].mean()
std_of_accuracy_rf_025=accuracy_rf_025.iloc[:, 1].std()
mean_of_F_rf_025=accuracy_rf_025.iloc[:, 2].mean()
std_of_F_rf_025=accuracy_rf_025.iloc[:, 2].std()

# RF 0.3
mean_of_accuracy_rf_03=accuracy_rf_03.iloc[:, 1].mean()
std_of_accuracy_rf_03=accuracy_rf_03.iloc[:, 1].std()
mean_of_F_rf_03=accuracy_rf_03.iloc[:, 2].mean()
std_of_F_rf_03=accuracy_rf_03.iloc[:, 2].std()

# RF 0.35
mean_of_accuracy_rf_035=accuracy_rf_035.iloc[:, 1].mean()
std_of_accuracy_rf_035=accuracy_rf_035.iloc[:, 1].std()
mean_of_F_rf_035=accuracy_rf_035.iloc[:, 2].mean()
std_of_F_rf_035=accuracy_rf_035.iloc[:, 2].std()

# RF 0.4
mean_of_accuracy_rf_04=accuracy_rf_04.iloc[:, 1].mean()
std_of_accuracy_rf_04=accuracy_rf_04.iloc[:, 1].std()
mean_of_F_rf_04=accuracy_rf_04.iloc[:, 2].mean()
std_of_F_rf_04=accuracy_rf_04.iloc[:, 2].std()

# RF 0.45
mean_of_accuracy_rf_045=accuracy_rf_045.iloc[:, 1].mean()
std_of_accuracy_rf_045=accuracy_rf_045.iloc[:, 1].std()
mean_of_F_rf_045=accuracy_rf_045.iloc[:, 2].mean()
std_of_F_rf_045=accuracy_rf_045.iloc[:, 2].std()

# RF 0.5
mean_of_accuracy_rf_05=accuracy_rf_05.iloc[:, 1].mean()
std_of_accuracy_rf_05=accuracy_rf_05.iloc[:, 1].std()
mean_of_F_rf_05=accuracy_rf_05.iloc[:, 2].mean()
std_of_F_rf_05=accuracy_rf_05.iloc[:, 2].std()

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.size']=10

x = [0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

y = [mean_of_accuracy_rf_02, mean_of_accuracy_rf_025, mean_of_accuracy_rf_03,
     mean_of_accuracy_rf_035, mean_of_accuracy_rf_04, mean_of_accuracy_rf_045,
     mean_of_accuracy_rf_05]

yerr = [std_of_accuracy_rf_02, std_of_accuracy_rf_025, std_of_accuracy_rf_03,
     std_of_accuracy_rf_035, std_of_accuracy_rf_04, std_of_accuracy_rf_045,
     std_of_accuracy_rf_05]

plt.errorbar(x, y, yerr=yerr, capsize=3, elinewidth=1)
plt.scatter(x, y)
for xi, yi in zip(x, y):
    plt.text(xi, yi + 0.01, f"{yi:.3f}", ha='center', va='bottom')
plt.xlabel('ratio of test data')
plt.ylabel('accuracy')
plt.ylim(0.6, 1.0)
plt.show()

import matplotlib.pyplot as plt
plt.rcParams['font.size']=10

x = [0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

y = [mean_of_F_rf_02, mean_of_F_rf_025, mean_of_F_rf_03,
     mean_of_F_rf_035, mean_of_F_rf_04, mean_of_F_rf_045,
     mean_of_F_rf_05]

yerr = [std_of_F_rf_02, std_of_F_rf_025, std_of_F_rf_03,
     std_of_F_rf_035, std_of_F_rf_04, std_of_F_rf_045,
     std_of_F_rf_05]

plt.errorbar(x, y, yerr=yerr, capsize=3, elinewidth=1)
plt.scatter(x, y)
for xi, yi in zip(x, y):
    plt.text(xi, yi + 0.01, f"{yi:.3f}", ha='center', va='bottom')
plt.xlabel('ratio of test data')
plt.ylabel('F-measure')
plt.ylim(0.58, 1.0)
plt.show()

# %% [markdown]
# # lta

# %%
import pandas as pd
accuracy_rf_02 = pd.read_csv('accuracy_rf_lta_0.2.csv', index_col=0) 
accuracy_rf_025 = pd.read_csv('accuracy_rf_lta_0.25.csv', index_col=0)
accuracy_rf_03 = pd.read_csv('accuracy_rf_lta_0.3.csv', index_col=0) 
accuracy_rf_035 = pd.read_csv('accuracy_rf_lta_0.35.csv', index_col=0) 
accuracy_rf_04 = pd.read_csv('accuracy_rf_lta_0.4.csv', index_col=0) 
accuracy_rf_045 = pd.read_csv('accuracy_rf_lta_0.45.csv', index_col=0) 
accuracy_rf_05 = pd.read_csv('accuracy_rf_lta_0.5.csv', index_col=0) 

# RF 0.2
mean_of_accuracy_rf_02=accuracy_rf_02.iloc[:, 1].mean()
std_of_accuracy_rf_02=accuracy_rf_02.iloc[:, 1].std()
mean_of_F_rf_02=accuracy_rf_02.iloc[:, 2].mean()
std_of_F_rf_02=accuracy_rf_02.iloc[:, 2].std()

# RF 0.25
mean_of_accuracy_rf_025=accuracy_rf_025.iloc[:, 1].mean()
std_of_accuracy_rf_025=accuracy_rf_025.iloc[:, 1].std()
mean_of_F_rf_025=accuracy_rf_025.iloc[:, 2].mean()
std_of_F_rf_025=accuracy_rf_025.iloc[:, 2].std()

# RF 0.3
mean_of_accuracy_rf_03=accuracy_rf_03.iloc[:, 1].mean()
std_of_accuracy_rf_03=accuracy_rf_03.iloc[:, 1].std()
mean_of_F_rf_03=accuracy_rf_03.iloc[:, 2].mean()
std_of_F_rf_03=accuracy_rf_03.iloc[:, 2].std()

# RF 0.35
mean_of_accuracy_rf_035=accuracy_rf_035.iloc[:, 1].mean()
std_of_accuracy_rf_035=accuracy_rf_035.iloc[:, 1].std()
mean_of_F_rf_035=accuracy_rf_035.iloc[:, 2].mean()
std_of_F_rf_035=accuracy_rf_035.iloc[:, 2].std()

# RF 0.4
mean_of_accuracy_rf_04=accuracy_rf_04.iloc[:, 1].mean()
std_of_accuracy_rf_04=accuracy_rf_04.iloc[:, 1].std()
mean_of_F_rf_04=accuracy_rf_04.iloc[:, 2].mean()
std_of_F_rf_04=accuracy_rf_04.iloc[:, 2].std()

# RF 0.45
mean_of_accuracy_rf_045=accuracy_rf_045.iloc[:, 1].mean()
std_of_accuracy_rf_045=accuracy_rf_045.iloc[:, 1].std()
mean_of_F_rf_045=accuracy_rf_045.iloc[:, 2].mean()
std_of_F_rf_045=accuracy_rf_045.iloc[:, 2].std()

# RF 0.5
mean_of_accuracy_rf_05=accuracy_rf_05.iloc[:, 1].mean()
std_of_accuracy_rf_05=accuracy_rf_05.iloc[:, 1].std()
mean_of_F_rf_05=accuracy_rf_05.iloc[:, 2].mean()
std_of_F_rf_05=accuracy_rf_05.iloc[:, 2].std()

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.size']=10

x = [0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

y = [mean_of_accuracy_rf_02, mean_of_accuracy_rf_025, mean_of_accuracy_rf_03,
     mean_of_accuracy_rf_035, mean_of_accuracy_rf_04, mean_of_accuracy_rf_045,
     mean_of_accuracy_rf_05]

yerr = [std_of_accuracy_rf_02, std_of_accuracy_rf_025, std_of_accuracy_rf_03,
     std_of_accuracy_rf_035, std_of_accuracy_rf_04, std_of_accuracy_rf_045,
     std_of_accuracy_rf_05]

plt.errorbar(x, y, yerr=yerr, capsize=3, elinewidth=1)
plt.scatter(x, y)
for xi, yi in zip(x, y):
    plt.text(xi, yi + 0.01, f"{yi:.3f}", ha='center', va='bottom')
plt.xlabel('ratio of test data')
plt.ylabel('accuracy')
plt.ylim(0.6, 1.0)
plt.show()

import matplotlib.pyplot as plt
plt.rcParams['font.size']=10

x = [0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

y = [mean_of_F_rf_02, mean_of_F_rf_025, mean_of_F_rf_03,
     mean_of_F_rf_035, mean_of_F_rf_04, mean_of_F_rf_045,
     mean_of_F_rf_05]

yerr = [std_of_F_rf_02, std_of_F_rf_025, std_of_F_rf_03,
     std_of_F_rf_035, std_of_F_rf_04, std_of_F_rf_045,
     std_of_F_rf_05]

plt.errorbar(x, y, yerr=yerr, capsize=3, elinewidth=1)
plt.scatter(x, y)
for xi, yi in zip(x, y):
    plt.text(xi, yi + 0.01, f"{yi:.3f}", ha='center', va='bottom')
plt.xlabel('ratio of test data')
plt.ylabel('F-measure')
plt.ylim(0.6, 1.0)
plt.show()

# %% [markdown]
# # d8r

# %%
import pandas as pd
accuracy_rf_02 = pd.read_csv('accuracy_rf_d8r_0.2.csv', index_col=0) 
accuracy_rf_025 = pd.read_csv('accuracy_rf_d8r_0.25.csv', index_col=0)
accuracy_rf_03 = pd.read_csv('accuracy_rf_d8r_0.3.csv', index_col=0) 
accuracy_rf_035 = pd.read_csv('accuracy_rf_d8r_0.35.csv', index_col=0) 
accuracy_rf_04 = pd.read_csv('accuracy_rf_d8r_0.4.csv', index_col=0) 
accuracy_rf_045 = pd.read_csv('accuracy_rf_d8r_0.45.csv', index_col=0) 
accuracy_rf_05 = pd.read_csv('accuracy_rf_d8r_0.5.csv', index_col=0) 

# RF 0.2
mean_of_accuracy_rf_02=accuracy_rf_02.iloc[:, 1].mean()
std_of_accuracy_rf_02=accuracy_rf_02.iloc[:, 1].std()
mean_of_F_rf_02=accuracy_rf_02.iloc[:, 2].mean()
std_of_F_rf_02=accuracy_rf_02.iloc[:, 2].std()

# RF 0.25
mean_of_accuracy_rf_025=accuracy_rf_025.iloc[:, 1].mean()
std_of_accuracy_rf_025=accuracy_rf_025.iloc[:, 1].std()
mean_of_F_rf_025=accuracy_rf_025.iloc[:, 2].mean()
std_of_F_rf_025=accuracy_rf_025.iloc[:, 2].std()

# RF 0.3
mean_of_accuracy_rf_03=accuracy_rf_03.iloc[:, 1].mean()
std_of_accuracy_rf_03=accuracy_rf_03.iloc[:, 1].std()
mean_of_F_rf_03=accuracy_rf_03.iloc[:, 2].mean()
std_of_F_rf_03=accuracy_rf_03.iloc[:, 2].std()

# RF 0.35
mean_of_accuracy_rf_035=accuracy_rf_035.iloc[:, 1].mean()
std_of_accuracy_rf_035=accuracy_rf_035.iloc[:, 1].std()
mean_of_F_rf_035=accuracy_rf_035.iloc[:, 2].mean()
std_of_F_rf_035=accuracy_rf_035.iloc[:, 2].std()

# RF 0.4
mean_of_accuracy_rf_04=accuracy_rf_04.iloc[:, 1].mean()
std_of_accuracy_rf_04=accuracy_rf_04.iloc[:, 1].std()
mean_of_F_rf_04=accuracy_rf_04.iloc[:, 2].mean()
std_of_F_rf_04=accuracy_rf_04.iloc[:, 2].std()

# RF 0.45
mean_of_accuracy_rf_045=accuracy_rf_045.iloc[:, 1].mean()
std_of_accuracy_rf_045=accuracy_rf_045.iloc[:, 1].std()
mean_of_F_rf_045=accuracy_rf_045.iloc[:, 2].mean()
std_of_F_rf_045=accuracy_rf_045.iloc[:, 2].std()

# RF 0.5
mean_of_accuracy_rf_05=accuracy_rf_05.iloc[:, 1].mean()
std_of_accuracy_rf_05=accuracy_rf_05.iloc[:, 1].std()
mean_of_F_rf_05=accuracy_rf_05.iloc[:, 2].mean()
std_of_F_rf_05=accuracy_rf_05.iloc[:, 2].std()

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.size']=10

x = [0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

y = [mean_of_accuracy_rf_02, mean_of_accuracy_rf_025, mean_of_accuracy_rf_03,
     mean_of_accuracy_rf_035, mean_of_accuracy_rf_04, mean_of_accuracy_rf_045,
     mean_of_accuracy_rf_05]

yerr = [std_of_accuracy_rf_02, std_of_accuracy_rf_025, std_of_accuracy_rf_03,
     std_of_accuracy_rf_035, std_of_accuracy_rf_04, std_of_accuracy_rf_045,
     std_of_accuracy_rf_05]

plt.errorbar(x, y, yerr=yerr, capsize=3, elinewidth=1)
plt.scatter(x, y)
for xi, yi in zip(x, y):
    plt.text(xi, yi + 0.01, f"{yi:.3f}", ha='center', va='bottom')
plt.xlabel('ratio of test data')
plt.ylabel('accuracy')
plt.ylim(0.6, 1.0)
plt.show()

import matplotlib.pyplot as plt
plt.rcParams['font.size']=10

x = [0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

y = [mean_of_F_rf_02, mean_of_F_rf_025, mean_of_F_rf_03,
     mean_of_F_rf_035, mean_of_F_rf_04, mean_of_F_rf_045,
     mean_of_F_rf_05]

yerr = [std_of_F_rf_02, std_of_F_rf_025, std_of_F_rf_03,
     std_of_F_rf_035, std_of_F_rf_04, std_of_F_rf_045,
     std_of_F_rf_05]

plt.errorbar(x, y, yerr=yerr, capsize=3, elinewidth=1)
plt.scatter(x, y)
for xi, yi in zip(x, y):
    plt.text(xi, yi + 0.01, f"{yi:.3f}", ha='center', va='bottom')
plt.xlabel('ratio of test data')
plt.ylabel('F-measure')
plt.ylim(0.6, 1.0)
plt.show()
