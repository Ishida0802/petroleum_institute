# %% [markdown]
# # can DT

# %%
import pandas as pd
accuracy_dt_02 = pd.read_csv('accuracy_dt_can_0.2.csv', index_col=0) 
accuracy_dt_025 = pd.read_csv('accuracy_dt_can_0.25.csv', index_col=0)
accuracy_dt_03 = pd.read_csv('accuracy_dt_can_0.3.csv', index_col=0) 
accuracy_dt_035 = pd.read_csv('accuracy_dt_can_0.35.csv', index_col=0) 
accuracy_dt_04 = pd.read_csv('accuracy_dt_can_0.4.csv', index_col=0) 
accuracy_dt_045 = pd.read_csv('accuracy_dt_can_0.45.csv', index_col=0) 
accuracy_dt_05 = pd.read_csv('accuracy_dt_can_0.5.csv', index_col=0) 

# DT 0.2
mean_of_accuracy_dt_02=accuracy_dt_02.iloc[:, 1].mean()
std_of_accuracy_dt_02=accuracy_dt_02.iloc[:, 1].std()
mean_of_F_dt_02=accuracy_dt_02.iloc[:, 2].mean()
std_of_F_dt_02=accuracy_dt_02.iloc[:, 2].std()

# DT 0.25
mean_of_accuracy_dt_025=accuracy_dt_025.iloc[:, 1].mean()
std_of_accuracy_dt_025=accuracy_dt_025.iloc[:, 1].std()
mean_of_F_dt_025=accuracy_dt_025.iloc[:, 2].mean()
std_of_F_dt_025=accuracy_dt_025.iloc[:, 2].std()

# DT 0.3
mean_of_accuracy_dt_03=accuracy_dt_03.iloc[:, 1].mean()
std_of_accuracy_dt_03=accuracy_dt_03.iloc[:, 1].std()
mean_of_F_dt_03=accuracy_dt_03.iloc[:, 2].mean()
std_of_F_dt_03=accuracy_dt_03.iloc[:, 2].std()

# DT 0.35
mean_of_accuracy_dt_035=accuracy_dt_035.iloc[:, 1].mean()
std_of_accuracy_dt_035=accuracy_dt_035.iloc[:, 1].std()
mean_of_F_dt_035=accuracy_dt_035.iloc[:, 2].mean()
std_of_F_dt_035=accuracy_dt_035.iloc[:, 2].std()

# DT 0.4
mean_of_accuracy_dt_04=accuracy_dt_04.iloc[:, 1].mean()
std_of_accuracy_dt_04=accuracy_dt_04.iloc[:, 1].std()
mean_of_F_dt_04=accuracy_dt_04.iloc[:, 2].mean()
std_of_F_dt_04=accuracy_dt_04.iloc[:, 2].std()

# DT 0.45
mean_of_accuracy_dt_045=accuracy_dt_045.iloc[:, 1].mean()
std_of_accuracy_dt_045=accuracy_dt_045.iloc[:, 1].std()
mean_of_F_dt_045=accuracy_dt_045.iloc[:, 2].mean()
std_of_F_dt_045=accuracy_dt_045.iloc[:, 2].std()

# DT 0.5
mean_of_accuracy_dt_05=accuracy_dt_05.iloc[:, 1].mean()
std_of_accuracy_dt_05=accuracy_dt_05.iloc[:, 1].std()
mean_of_F_dt_05=accuracy_dt_05.iloc[:, 2].mean()
std_of_F_dt_05=accuracy_dt_05.iloc[:, 2].std()

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.size']=10

x = [0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

y = [mean_of_accuracy_dt_02, mean_of_accuracy_dt_025, mean_of_accuracy_dt_03,
     mean_of_accuracy_dt_035, mean_of_accuracy_dt_04, mean_of_accuracy_dt_045,
     mean_of_accuracy_dt_05]

yerr = [std_of_accuracy_dt_02, std_of_accuracy_dt_025, std_of_accuracy_dt_03,
     std_of_accuracy_dt_035, std_of_accuracy_dt_04, std_of_accuracy_dt_045,
     std_of_accuracy_dt_05]

plt.errorbar(x, y, yerr=yerr, capsize=3, elinewidth=1)
plt.scatter(x, y)
for xi, yi in zip(x, y):
    plt.text(xi, yi + 0.01, f"{yi:.3f}", ha='center', va='bottom')
plt.xlabel('ratio of test data')
plt.ylabel('accuracy')
plt.ylim(0.6, 1.0)
plt.show()

import matplotlib.pyplot as plt
plt.rcParams['font.size']=10

x = [0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

y = [mean_of_F_dt_02, mean_of_F_dt_025, mean_of_F_dt_03,
     mean_of_F_dt_035, mean_of_F_dt_04, mean_of_F_dt_045,
     mean_of_F_dt_05]

yerr = [std_of_F_dt_02, std_of_F_dt_025, std_of_F_dt_03,
     std_of_F_dt_035, std_of_F_dt_04, std_of_F_dt_045,
     std_of_F_dt_05]

plt.errorbar(x, y, yerr=yerr, capsize=3, elinewidth=1)
plt.scatter(x, y)
plt.scatter(0.25, 0.919, color='red', label='(0.25, 0.923)')
for xi, yi in zip(x, y):
    plt.text(xi, yi + 0.01, f"{yi:.3f}", ha='center', va='bottom')
plt.xlabel('ratio of test data')
plt.ylabel('F-measure')
plt.ylim(0.6, 1.0)
plt.show()

# %%
mean_of_F_dt_02
# Out:
# 0.7684700972311757

# %% [markdown]
# # can RF

# %%
import pandas as pd
accuracy_rf_02 = pd.read_csv('accuracy_rf_can_0.2.csv', index_col=0) 
accuracy_rf_025 = pd.read_csv('accuracy_rf_can_0.25.csv', index_col=0)
accuracy_rf_03 = pd.read_csv('accuracy_rf_can_0.3.csv', index_col=0) 
accuracy_rf_035 = pd.read_csv('accuracy_rf_can_0.35.csv', index_col=0) 
accuracy_rf_04 = pd.read_csv('accuracy_rf_can_0.4.csv', index_col=0) 
accuracy_rf_045 = pd.read_csv('accuracy_rf_can_0.45.csv', index_col=0) 
accuracy_rf_05 = pd.read_csv('accuracy_rf_can_0.5.csv', index_col=0) 

# RF 0.2
mean_of_accuracy_rf_02=accuracy_rf_02.iloc[:, 1].mean()
std_of_accuracy_rf_02=accuracy_rf_02.iloc[:, 1].std()
mean_of_F_rf_02=accuracy_rf_02.iloc[:, 2].mean()
std_of_F_rf_02=accuracy_rf_02.iloc[:, 2].std()

# RF 0.25
mean_of_accuracy_rf_025=accuracy_rf_025.iloc[:, 1].mean()
std_of_accuracy_rf_025=accuracy_rf_025.iloc[:, 1].std()
mean_of_F_rf_025=accuracy_rf_025.iloc[:, 2].mean()
std_of_F_rf_025=accuracy_rf_025.iloc[:, 2].std()

# RF 0.3
mean_of_accuracy_rf_03=accuracy_rf_03.iloc[:, 1].mean()
std_of_accuracy_rf_03=accuracy_rf_03.iloc[:, 1].std()
mean_of_F_rf_03=accuracy_rf_03.iloc[:, 2].mean()
std_of_F_rf_03=accuracy_rf_03.iloc[:, 2].std()

# DT 0.35
mean_of_accuracy_rf_035=accuracy_rf_035.iloc[:, 1].mean()
std_of_accuracy_rf_035=accuracy_rf_035.iloc[:, 1].std()
mean_of_F_rf_035=accuracy_rf_035.iloc[:, 2].mean()
std_of_F_rf_035=accuracy_rf_035.iloc[:, 2].std()

# RF 0.4
mean_of_accuracy_rf_04=accuracy_rf_04.iloc[:, 1].mean()
std_of_accuracy_rf_04=accuracy_rf_04.iloc[:, 1].std()
mean_of_F_rf_04=accuracy_rf_04.iloc[:, 2].mean()
std_of_F_rf_04=accuracy_rf_04.iloc[:, 2].std()

# RF 0.45
mean_of_accuracy_rf_045=accuracy_rf_045.iloc[:, 1].mean()
std_of_accuracy_rf_045=accuracy_rf_045.iloc[:, 1].std()
mean_of_F_rf_045=accuracy_rf_045.iloc[:, 2].mean()
std_of_F_rf_045=accuracy_rf_045.iloc[:, 2].std()

# RF 0.5
mean_of_accuracy_rf_05=accuracy_rf_05.iloc[:, 1].mean()
std_of_accuracy_rf_05=accuracy_rf_05.iloc[:, 1].std()
mean_of_F_rf_05=accuracy_rf_05.iloc[:, 2].mean()
std_of_F_rf_05=accuracy_rf_05.iloc[:, 2].std()

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.size']=12

x = [0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

y = [mean_of_accuracy_rf_02, mean_of_accuracy_rf_025, mean_of_accuracy_rf_03,
     mean_of_accuracy_rf_035, mean_of_accuracy_rf_04, mean_of_accuracy_rf_045,
     mean_of_accuracy_rf_05]

yerr = [std_of_accuracy_rf_02, std_of_accuracy_rf_025, std_of_accuracy_rf_03,
     std_of_accuracy_rf_035, std_of_accuracy_rf_04, std_of_accuracy_rf_045,
     std_of_accuracy_rf_05]

plt.errorbar(x, y, yerr=yerr, capsize=3, elinewidth=1)
plt.scatter(x, y)
for xi, yi in zip(x, y):
    plt.text(xi, yi + 0.01, f"{yi:.3f}", ha='center', va='bottom')
plt.xlabel('ratio of test data')
plt.ylabel('accuracy')
plt.ylim(0.6, 1.0)
plt.show()

import matplotlib.pyplot as plt
plt.rcParams['font.size']=12

x = [0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

y = [mean_of_F_rf_02, mean_of_F_rf_025, mean_of_F_rf_03,
     mean_of_F_rf_035, mean_of_F_rf_04, mean_of_F_rf_045,
     mean_of_F_rf_05]

yerr = [std_of_F_rf_02, std_of_F_rf_025, std_of_F_rf_03,
     std_of_F_rf_035, std_of_F_rf_04, std_of_F_rf_045,
     std_of_F_rf_05]

plt.errorbar(x, y, yerr=yerr, capsize=3, elinewidth=1)
plt.scatter(x, y)
plt.scatter(0.25, 0.877, color='red', label='(0.25, 0.923)')
for xi, yi in zip(x, y):
    plt.text(xi, yi + 0.01, f"{yi:.3f}", ha='center', va='bottom')
plt.xlabel('ratio of test data')
plt.ylabel('F-measure')
plt.ylim(0.6, 1.0)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.size']=12

x = [0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

y = [mean_of_accuracy_rf_02, mean_of_accuracy_rf_025, mean_of_accuracy_rf_03,
     mean_of_accuracy_rf_035, mean_of_accuracy_rf_04, mean_of_accuracy_rf_045,
     mean_of_accuracy_rf_05]

yerr = [std_of_accuracy_rf_02, std_of_accuracy_rf_025, std_of_accuracy_rf_03,
     std_of_accuracy_rf_035, std_of_accuracy_rf_04, std_of_accuracy_rf_045,
     std_of_accuracy_rf_05]

plt.errorbar(x, y, yerr=yerr, capsize=3, elinewidth=1)
plt.scatter(x, y)
for xi, yi in zip(x, y):
    plt.text(xi, yi + 0.01, f"{yi:.3f}", ha='center', va='bottom')
plt.xlabel('ratio of test data')
plt.ylabel('accuracy')
plt.ylim(0.6, 1.0)
plt.show()

import matplotlib.pyplot as plt
plt.rcParams['font.size']=12

x = [0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

y = [mean_of_F_rf_02, mean_of_F_rf_025, mean_of_F_rf_03,
     mean_of_F_rf_035, mean_of_F_rf_04, mean_of_F_rf_045,
     mean_of_F_rf_05]

yerr = [std_of_F_rf_02, std_of_F_rf_025, std_of_F_rf_03,
     std_of_F_rf_035, std_of_F_rf_04, std_of_F_rf_045,
     std_of_F_rf_05]

plt.errorbar(x, y, yerr=yerr, capsize=3, elinewidth=1)
plt.scatter(x, y)
for xi, yi in zip(x, y):
    plt.text(xi, yi + 0.01, f"{yi:.3f}", ha='center', va='bottom')
plt.xlabel('ratio of test data')
plt.ylabel('F-measure')
plt.ylim(0.6, 1.0)
plt.show()

# %% [markdown]
# # can XGB

# %%
import pandas as pd
accuracy_xgb_02 = pd.read_csv('accuracy_xgb_can_0.2.csv', index_col=0) 
accuracy_xgb_025 = pd.read_csv('accuracy_xgb_can_0.25.csv', index_col=0)
accuracy_xgb_03 = pd.read_csv('accuracy_xgb_can_0.3.csv', index_col=0) 
accuracy_xgb_035 = pd.read_csv('accuracy_xgb_can_0.35.csv', index_col=0) 
accuracy_xgb_04 = pd.read_csv('accuracy_xgb_can_0.4.csv', index_col=0) 
accuracy_xgb_045 = pd.read_csv('accuracy_xgb_can_0.45.csv', index_col=0) 
accuracy_xgb_05 = pd.read_csv('accuracy_xgb_can_0.5.csv', index_col=0) 

# XGB 0.2
mean_of_accuracy_xgb_02=accuracy_xgb_02.iloc[:, 1].mean()
std_of_accuracy_xgb_02=accuracy_xgb_02.iloc[:, 1].std()
mean_of_F_xgb_02=accuracy_xgb_02.iloc[:, 2].mean()
std_of_F_xgb_02=accuracy_xgb_02.iloc[:, 2].std()

# XGB 0.25
mean_of_accuracy_xgb_025=accuracy_xgb_025.iloc[:, 1].mean()
std_of_accuracy_xgb_025=accuracy_xgb_025.iloc[:, 1].std()
mean_of_F_xgb_025=accuracy_xgb_025.iloc[:, 2].mean()
std_of_F_xgb_025=accuracy_xgb_025.iloc[:, 2].std()

# XGB 0.3
mean_of_accuracy_xgb_03=accuracy_xgb_03.iloc[:, 1].mean()
std_of_accuracy_xgb_03=accuracy_xgb_03.iloc[:, 1].std()
mean_of_F_xgb_03=accuracy_xgb_03.iloc[:, 2].mean()
std_of_F_xgb_03=accuracy_xgb_03.iloc[:, 2].std()

# XGB 0.35
mean_of_accuracy_xgb_035=accuracy_xgb_035.iloc[:, 1].mean()
std_of_accuracy_xgb_035=accuracy_xgb_035.iloc[:, 1].std()
mean_of_F_xgb_035=accuracy_xgb_035.iloc[:, 2].mean()
std_of_F_xgb_035=accuracy_xgb_035.iloc[:, 2].std()

# XGB 0.4
mean_of_accuracy_xgb_04=accuracy_xgb_04.iloc[:, 1].mean()
std_of_accuracy_xgb_04=accuracy_xgb_04.iloc[:, 1].std()
mean_of_F_xgb_04=accuracy_xgb_04.iloc[:, 2].mean()
std_of_F_xgb_04=accuracy_xgb_04.iloc[:, 2].std()

# XGB 0.45
mean_of_accuracy_xgb_045=accuracy_xgb_045.iloc[:, 1].mean()
std_of_accuracy_xgb_045=accuracy_xgb_045.iloc[:, 1].std()
mean_of_F_xgb_045=accuracy_xgb_045.iloc[:, 2].mean()
std_of_F_xgb_045=accuracy_xgb_045.iloc[:, 2].std()

# XGB 0.5
mean_of_accuracy_xgb_05=accuracy_xgb_05.iloc[:, 1].mean()
std_of_accuracy_xgb_05=accuracy_xgb_05.iloc[:, 1].std()
mean_of_F_xgb_05=accuracy_xgb_05.iloc[:, 2].mean()
std_of_F_xgb_05=accuracy_xgb_05.iloc[:, 2].std()

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.size']=10

x = [0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

y = [mean_of_accuracy_xgb_02, mean_of_accuracy_xgb_025, mean_of_accuracy_xgb_03,
     mean_of_accuracy_xgb_035, mean_of_accuracy_xgb_04, mean_of_accuracy_xgb_045,
     mean_of_accuracy_xgb_05]

yerr = [std_of_accuracy_xgb_02, std_of_accuracy_xgb_025, std_of_accuracy_xgb_03,
     std_of_accuracy_xgb_035, std_of_accuracy_xgb_04, std_of_accuracy_xgb_045,
     std_of_accuracy_xgb_05]

plt.errorbar(x, y, yerr=yerr, capsize=3, elinewidth=1)
plt.scatter(x, y)
for xi, yi in zip(x, y):
    plt.text(xi, yi + 0.01, f"{yi:.3f}", ha='center', va='bottom')
plt.xlabel('ratio of test data')
plt.ylabel('accuracy')
plt.ylim(0.6, 1.0)
plt.show()

import matplotlib.pyplot as plt
plt.rcParams['font.size']=10

x = [0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

y = [mean_of_F_xgb_02, mean_of_F_xgb_025, mean_of_F_xgb_03,
     mean_of_F_xgb_035, mean_of_F_xgb_04, mean_of_F_xgb_045,
     mean_of_F_xgb_05]

yerr = [std_of_F_xgb_02, std_of_F_xgb_025, std_of_F_xgb_03,
     std_of_F_xgb_035, std_of_F_xgb_04, std_of_F_xgb_045,
     std_of_F_xgb_05]

plt.errorbar(x, y, yerr=yerr, capsize=3, elinewidth=1)
plt.scatter(x, y)
plt.scatter(0.25, 0.8, color='red', label='(0.25, 0.923)')
for xi, yi in zip(x, y):
    plt.text(xi, yi + 0.01, f"{yi:.3f}", ha='center', va='bottom')
plt.xlabel('ratio of test data')
plt.ylabel('F-measure')
plt.ylim(0.6, 1.0)
plt.show()

# %% [markdown]
# # can LGBM

# %%
import pandas as pd
accuracy_lgbm_02 = pd.read_csv('accuracy_lgbm_can_0.2.csv', index_col=0) 
accuracy_lgbm_025 = pd.read_csv('accuracy_lgbm_can_0.25.csv', index_col=0)
accuracy_lgbm_03 = pd.read_csv('accuracy_lgbm_can_0.3.csv', index_col=0) 
accuracy_lgbm_035 = pd.read_csv('accuracy_lgbm_can_0.35.csv', index_col=0) 
accuracy_lgbm_04 = pd.read_csv('accuracy_lgbm_can_0.4.csv', index_col=0) 
accuracy_lgbm_045 = pd.read_csv('accuracy_lgbm_can_0.45.csv', index_col=0) 
accuracy_lgbm_05 = pd.read_csv('accuracy_lgbm_can_0.5.csv', index_col=0) 

# LGBM 0.2
mean_of_accuracy_lgbm_02=accuracy_lgbm_02.iloc[:, 1].mean()
std_of_accuracy_lgbm_02=accuracy_lgbm_02.iloc[:, 1].std()
mean_of_F_lgbm_02=accuracy_lgbm_02.iloc[:, 2].mean()
std_of_F_lgbm_02=accuracy_lgbm_02.iloc[:, 2].std()

# LGBM 0.25
mean_of_accuracy_lgbm_025=accuracy_lgbm_025.iloc[:, 1].mean()
std_of_accuracy_lgbm_025=accuracy_lgbm_025.iloc[:, 1].std()
mean_of_F_lgbm_025=accuracy_lgbm_025.iloc[:, 2].mean()
std_of_F_lgbm_025=accuracy_lgbm_025.iloc[:, 2].std()

# LGBM 0.3
mean_of_accuracy_lgbm_03=accuracy_lgbm_03.iloc[:, 1].mean()
std_of_accuracy_lgbm_03=accuracy_lgbm_03.iloc[:, 1].std()
mean_of_F_lgbm_03=accuracy_lgbm_03.iloc[:, 2].mean()
std_of_F_lgbm_03=accuracy_lgbm_03.iloc[:, 2].std()

# LGBM 0.35
mean_of_accuracy_lgbm_035=accuracy_lgbm_035.iloc[:, 1].mean()
std_of_accuracy_lgbm_035=accuracy_lgbm_035.iloc[:, 1].std()
mean_of_F_lgbm_035=accuracy_lgbm_035.iloc[:, 2].mean()
std_of_F_lgbm_035=accuracy_lgbm_035.iloc[:, 2].std()

# LGBM 0.4
mean_of_accuracy_lgbm_04=accuracy_lgbm_04.iloc[:, 1].mean()
std_of_accuracy_lgbm_04=accuracy_lgbm_04.iloc[:, 1].std()
mean_of_F_lgbm_04=accuracy_lgbm_04.iloc[:, 2].mean()
std_of_F_lgbm_04=accuracy_lgbm_04.iloc[:, 2].std()

# LGBM 0.45
mean_of_accuracy_lgbm_045=accuracy_lgbm_045.iloc[:, 1].mean()
std_of_accuracy_lgbm_045=accuracy_lgbm_045.iloc[:, 1].std()
mean_of_F_lgbm_045=accuracy_lgbm_045.iloc[:, 2].mean()
std_of_F_lgbm_045=accuracy_lgbm_045.iloc[:, 2].std()

# LGBM 0.5
mean_of_accuracy_lgbm_05=accuracy_lgbm_05.iloc[:, 1].mean()
std_of_accuracy_lgbm_05=accuracy_lgbm_05.iloc[:, 1].std()
mean_of_F_lgbm_05=accuracy_lgbm_05.iloc[:, 2].mean()
std_of_F_lgbm_05=accuracy_lgbm_05.iloc[:, 2].std()

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.size']=10

x = [0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

y = [mean_of_accuracy_lgbm_02, mean_of_accuracy_lgbm_025, mean_of_accuracy_lgbm_03,
     mean_of_accuracy_lgbm_035, mean_of_accuracy_lgbm_04, mean_of_accuracy_lgbm_045,
     mean_of_accuracy_lgbm_05]

yerr = [std_of_accuracy_lgbm_02, std_of_accuracy_lgbm_025, std_of_accuracy_lgbm_03,
     std_of_accuracy_lgbm_035, std_of_accuracy_lgbm_04, std_of_accuracy_lgbm_045,
     std_of_accuracy_xgb_05]

plt.errorbar(x, y, yerr=yerr, capsize=3, elinewidth=1)
plt.scatter(x, y)
for xi, yi in zip(x, y):
    plt.text(xi, yi + 0.01, f"{yi:.3f}", ha='center', va='bottom')
plt.xlabel('ratio of test data')
plt.ylabel('accuracy')
plt.ylim(0.6, 1.0)
plt.show()

import matplotlib.pyplot as plt
plt.rcParams['font.size']=10

x = [0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

y = [mean_of_F_lgbm_02, mean_of_F_lgbm_025, mean_of_F_lgbm_03,
     mean_of_F_lgbm_035, mean_of_F_lgbm_04, mean_of_F_lgbm_045,
     mean_of_F_lgbm_05]

yerr = [std_of_F_lgbm_02, std_of_F_lgbm_025, std_of_F_lgbm_03,
     std_of_F_lgbm_035, std_of_F_lgbm_04, std_of_F_lgbm_045,
     std_of_F_lgbm_05]

plt.errorbar(x, y, yerr=yerr, capsize=3, elinewidth=1)
plt.scatter(x, y)
plt.scatter(0.25, 0.809, color='red', label='(0.25, 0.923)')
for xi, yi in zip(x, y):
    plt.text(xi, yi + 0.01, f"{yi:.3f}", ha='center', va='bottom')
plt.xlabel('ratio of test data')
plt.ylabel('F-measure')
plt.ylim(0.6, 1.0)
plt.show()
